# %% [markdown]
# <a href="https://colab.research.google.com/github/oliveiragabriel07/imersaodados3/blob/main/Notebooks/Aula_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression='zip')

# %%
dados_resultados['n_moa'] = dados_resultados.sum(axis = 'columns')

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] > 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      1       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      1       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      1       True
# ...

# %%
x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'droga'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo']) 
x.head()
# Out:
#       g-0     g-1     g-2     g-3  ...  dose_D2  tempo_24  tempo_48  tempo_72
# 0  1.0620  0.5577 -0.2479 -0.6208  ...        0         1         0         0
# 1  0.0743  0.4087  0.2991  0.0604  ...        0         0         0         1
# 2  0.6280  0.5817  1.5540 -0.0764  ...        0         0         1         0
# 3 -0.5138 -0.2491 -0.2656  0.5288  ...        0         0         1         0
# 4 -0.3254 -0.4009  0.9700  0.6919  ...        1         0         0         1
#
# [5 rows x 879 columns]

# %%
y = dados_combinados['ativo_moa']
y.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: ativo_moa, dtype: bool

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def score_model(model, x, y):
  x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)
  model.fit(x_treino, y_treino)
  previsao = model.predict(x_teste)
  return accuracy_score(y_teste, previsao)

# %%
from sklearn.dummy import DummyClassifier

modelo = DummyClassifier('most_frequent')
score_model(modelo, x, y)
# Out:
# 0.6067604450976275

# %% [markdown]
# ###Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %%
from sklearn.svm import SVC

modelo = SVC()
score_model(modelo, x, y)
# Out:
# 0.6928406466512702

# %% [markdown]
# ###Desafio 02: Estude a documentação do Sklearn.
#
# https://scikit-learn.org/stable/user_guide.html

# %% [markdown]
# ###Desafio 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo' choosing the right estimator
#
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html

# %% [markdown]
# ###Desafio 04: Teste outras problemas (perguntas). 0, 1 ou +.

# %%
y_2 = dados_combinados['ativo_pelo_menos_2']
y_2.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: ativo_pelo_menos_2, dtype: bool

# %%
from sklearn.dummy import DummyClassifier

modelo = DummyClassifier('most_frequent')
score_model(modelo, x, y_2)
# Out:
# 0.9195884946462314

# %%
from sklearn.svm import SVC

modelo = SVC()
score_model(modelo, x, y_2)
# Out:
# 0.9510812513121982

# %% [markdown]
# ###Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.

# %%
dados_combinados['droga_alvo'] = dados_combinados['droga'] == '87d714366'

# %%
y_droga_alvo = dados_combinados['droga_alvo']

# %%
from sklearn.dummy import DummyClassifier

modelo = DummyClassifier('most_frequent')
score_model(modelo, x, y_droga_alvo)
# Out:
# 0.9697669536006719

# %%
from sklearn.svm import SVC

modelo = SVC()
score_model(modelo, x, y_droga_alvo)
# Out:
# 0.9979004828889355

# %% [markdown]
# ###Desafio 06: Resumo do que você aprendeu com os dados
#
# Tivemos uma introdução sobre o uso de intelegência artificial para realizar a previsão de resultados. Conhecemos um pouco mais sobre a biblioteca scikitlearn e alguns modelos de IA que podem ser aplicados em diferentes situações.
