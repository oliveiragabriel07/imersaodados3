# %% [markdown]
# <a href="https://colab.research.google.com/github/oliveiragabriel07/imersaodados3/blob/main/Notebooks/Aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %%
dados_renomeados = dados_resultados.rename(columns=lambda x: x.split('_')[-1]).drop('id', axis='columns')
dados_renomeados.groupby(dados_renomeados.columns, axis='columns').sum().sum().sort_values(ascending=False).head(10)
# Out:
# inhibitor            9693
# antagonist           3449
# agonist              2330
# blocker               323
# agent                 150
# activator             115
# local                  80
# immunosuppressant      73
# anti-inflammatory      73
# antioxidant            73
# dtype: int64

# %% [markdown]
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression='zip')

# %%
dados_resultados['n_moa'] = dados_resultados.sum(axis = 'columns')

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] > 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      1       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      1       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      1       True
# ...

# %%
dados_combinados['eh_controle'] = dados_combinados['tratamento'] == "com_controle"
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['tempo_24'] = dados_combinados['tempo'] == 24
dados_combinados['tempo_48'] = dados_combinados['tempo'] == 48
dados_combinados['tempo_72'] = dados_combinados['tempo'] == 72

dados_combinados
# Out:
#                  id    tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0      id_000644bb2     com_droga     24  ...     True    False     False
# 1      id_000779bfc     com_droga     72  ...    False    False      True
# 2      id_000a6266a     com_droga     48  ...    False     True     False
# 3      id_0015fd391     com_droga     48  ...    False     True     False
# 4      id_001626bd3     com_droga     72  ...    False    False      True
# ...             ...           ...    ...  ...      ...      ...       ...
# 23809  id_fffb1ceed     com_droga     24  ...     True    False     False
# 23810  id_fffb70c0c     com_droga     24  ...     True    False     False
# 23811  id_fffc1c3f4  com_controle     48  ...    False     True     False
# 23812  id_fffcb9e7c     com_droga     24  ...     True    False     False
# 23813  id_ffffdd77b     com_droga     72  ...    False    False      True
#
# [23814 rows x 883 columns]

# %% [markdown]
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot(composto, ax, hue):
  dados_concatenados = pd.concat([dados_combinados.query('droga in @composto'), dados_combinados.query('droga == @controle')])
  sns.boxplot(data=dados_concatenados, y='g-0', x='tratamento', hue=hue, ax=ax)
  ax.set_title(composto)

controle = dados_combinados.query('tratamento == "com_controle"')['droga'].unique()[0]
compostos = dados_combinados.drop(dados_combinados.query('droga == @controle').index)['droga'].value_counts().index[:4]
compostos

fig, axs = plt.subplots(2,2,figsize=(20,20))
plot(composto=compostos[0], ax = axs[0][0], hue='dose')
plot(composto=compostos[1], ax = axs[0][1], hue='dose')
plot(composto=compostos[2], ax = axs[1][0], hue='dose')
plot(composto=compostos[3], ax = axs[1][1], hue='dose')
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize=(20,20))
plot(composto=compostos[0], ax = axs[0][0], hue='tempo')
plot(composto=compostos[1], ax = axs[0][1], hue='tempo')
plot(composto=compostos[2], ax = axs[1][0], hue='tempo')
plot(composto=compostos[3], ax = axs[1][1], hue='tempo')
plt.show()

# %% [markdown]
# ###Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
dados_combinados.groupby('droga').filter(lambda x: x['ativo_moa'].nunique() > 1)
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, droga, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 883 columns]

# %% [markdown]
# ###Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %%
dados_combinados.groupby('droga').filter(lambda x: x['n_moa'].nunique() > 1)
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, droga, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 883 columns]

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Aparentemente, as doses e tempo dos experimentos não interferem nos MOAs, embora resultem em valores diferentes para manifestação dos genes
